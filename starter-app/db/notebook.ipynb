# %%
import pandas as pd

df = pd.read_stata("../data/datasets/RW_LFS2022.dta")

print(f"{len(df)} rows, {df.shape[1]} columns")
df.head()
# Out:
# 70424 rows, 239 columns
#    PSU_NO  QH_NO    HHID       pid     province Code_UR    code_dis  LFS_year  \
# 0    1791      1  179101  17910101  Kigali city   Urban  Nyarugenge      2022
# 1    1791      1  179101  17910103  Kigali city   Urban  Nyarugenge      2022
# 2    1791      1  179101  17910102  Kigali city   Urban  Nyarugenge      2022
# 3    1791      2  179102  17910201  Kigali city   Urban  Nyarugenge      2022
# 4    1791      3  179103  17910305  Kigali city   Urban  Nyarugenge      2022
#
#      weight2     A01  ...  LU4 TRUR                           indb05  \
# 0  46.284462  Female  ...  0.0  0.0  Social Science business and art
# 1  46.284462    Male  ...  NaN  NaN                              NaN
# 2  46.284462    Male  ...  NaN  NaN                              NaN
# 3  46.284462    Male  ...  0.0  0.0  Social Science business and art
# 4  46.284462  Female  ...  NaN  NaN                              NaN
#
#                                   isco2digit  \
# ...
